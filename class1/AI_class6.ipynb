# %%
def sum_3(a,b):
  c=a+b
  print(c)

# %%
def sum_1(a,b):
  c=a+b
  return c

# %%
sum(4,5)
# Out:
# 9

# %%
sum_1(4,7)
# Out:
# 11

# %%
def sum_2(a,b):
  c=a+b
  return a,b,c

# %%
sum_2(6,7)
# Out:
# (6, 7, 13)

# %%
sum_3(5,8)
# Out:
# 13

# %%
def t(a,b):
  c=a+b
  return a,b,c

# %%
d =t(1,2)

# %%
d
# Out:
# (1, 2, 3)

# %%
e,f,g=t(1,2)

# %%
e
# Out:
# 1

# %%
f
# Out:
# 2

# %%
g
# Out:
# 3

# %%
e,f=t(1,2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-91c3ec11823c> in <cell line: 1>()
# ----> 1 e,f=t(1,2)
#
# ValueError: too many values to unpack (expected 2)

# %%
def num(*args, name):
  print(sum(args), name)

# %%
num(1,2,3,4,5,6, name="rla")
# Out:
# 21 rla

# %%
num(1,2,3,4,5,6, name="rla")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-7eda0ab81ea0> in <cell line: 1>()
# ----> 1 num(1,2,3,4,5,6, name="rla")
#
# <ipython-input-51-16adb4519cdc> in num(name, *args)
#       1 def num(*args, name):
# ----> 2   print(sum(args), name)
#
# TypeError: sum() missing 1 required positional argument: 'b'
